# %% [markdown]
# # Working with R in JupyterLabs

# %%
# %%capture
# !pip install rpy2

# %%
# %load_ext rpy2.ipython
# Out:
# C:\Users\dudas\anaconda3\lib\site-packages\rpy2\robjects\packages.py:366: UserWarning: The symbol 'quartz' is not in this R namespace/package.
#   warnings.warn(

# %%
# %%R
# install.packages.zip("https://cran.r-project.org/bin/windows/contrib/4.2/ggplot2_3.3.3.zip")
# Out:
# R[write to console]: Installing package into 'C:/Users/dudas/OneDrive - The Pennsylvania State University/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
#
# R[write to console]: also installing the dependencies 'colorspace', 'cli', 'crayon', 'utf8', 'farver', 'labeling', 'lifecycle', 'munsell', 'R6', 'RColorBrewer', 'viridisLite', 'ellipsis', 'fansi', 'magrittr', 'pillar', 'pkgconfig', 'vctrs', 'digest', 'glue', 'gtable', 'isoband', 'rlang', 'scales', 'tibble', 'withr'
#   There is a binary version available but the source version is later:
#       binary source needs_compilation
# fansi  0.4.2  0.5.0              TRUE
#
#   Binaries will be installed
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/colorspace_2.0-1.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 2640956 bytes (2.5 MB)
#
# R[write to console]: downloaded 2.5 MB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/cli_2.5.0.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 534156 bytes (521 KB)
#
# R[write to console]: downloaded 521 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/crayon_1.4.1.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 141800 bytes (138 KB)
#
# R[write to console]: downloaded 138 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/utf8_1.2.1.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 209858 bytes (204 KB)
#
# R[write to console]: downloaded 204 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/farver_2.1.0.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 1752206 bytes (1.7 MB)
#
# R[write to console]: downloaded 1.7 MB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/labeling_0.4.2.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 62808 bytes (61 KB)
#
# R[write to console]: downloaded 61 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/lifecycle_1.0.0.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 111163 bytes (108 KB)
#
# R[write to console]: downloaded 108 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/munsell_0.5.0.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 244784 bytes (239 KB)
#
# R[write to console]: downloaded 239 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/R6_2.5.0.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 84102 bytes (82 KB)
#
# R[write to console]: downloaded 82 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/RColorBrewer_1.1-2.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 55593 bytes (54 KB)
#
# R[write to console]: downloaded 54 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/viridisLite_0.4.0.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 1299472 bytes (1.2 MB)
#
# R[write to console]: downloaded 1.2 MB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/ellipsis_0.3.2.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 49171 bytes (48 KB)
#
# R[write to console]: downloaded 48 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/fansi_0.4.2.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 224354 bytes (219 KB)
#
# R[write to console]: downloaded 219 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/magrittr_2.0.1.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 235990 bytes (230 KB)
#
# R[write to console]: downloaded 230 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/pillar_1.6.1.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 1025394 bytes (1001 KB)
#
# R[write to console]: downloaded 1001 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/pkgconfig_2.0.3.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 22276 bytes (21 KB)
#
# R[write to console]: downloaded 21 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/vctrs_0.3.8.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 1252064 bytes (1.2 MB)
#
# R[write to console]: downloaded 1.2 MB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/digest_0.6.27.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 268512 bytes (262 KB)
#
# R[write to console]: downloaded 262 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/glue_1.4.2.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 154925 bytes (151 KB)
#
# R[write to console]: downloaded 151 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/gtable_0.3.0.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 434134 bytes (423 KB)
#
# R[write to console]: downloaded 423 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/isoband_0.2.4.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 3062256 bytes (2.9 MB)
#
# R[write to console]: downloaded 2.9 MB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/rlang_0.4.11.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 1201643 bytes (1.1 MB)
#
# R[write to console]: downloaded 1.1 MB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/scales_1.1.1.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 563067 bytes (549 KB)
#
# R[write to console]: downloaded 549 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/tibble_3.1.2.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 824717 bytes (805 KB)
#
# R[write to console]: downloaded 805 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/withr_2.4.2.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 213120 bytes (208 KB)
#
# R[write to console]: downloaded 208 KB
#
#
# R[write to console]: trying URL 'https://cran.case.edu/bin/windows/contrib/4.1/ggplot2_3.3.3.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 4071463 bytes (3.9 MB)
#
# R[write to console]: downloaded 3.9 MB
# package 'colorspace' successfully unpacked and MD5 sums checked
# package 'cli' successfully unpacked and MD5 sums checked
# package 'crayon' successfully unpacked and MD5 sums checked
# package 'utf8' successfully unpacked and MD5 sums checked
# package 'farver' successfully unpacked and MD5 sums checked
# package 'labeling' successfully unpacked and MD5 sums checked
# package 'lifecycle' successfully unpacked and MD5 sums checked
# package 'munsell' successfully unpacked and MD5 sums checked
# package 'R6' successfully unpacked and MD5 sums checked
# package 'RColorBrewer' successfully unpacked and MD5 sums checked
# package 'viridisLite' successfully unpacked and MD5 sums checked
# package 'ellipsis' successfully unpacked and MD5 sums checked
# package 'fansi' successfully unpacked and MD5 sums checked
# package 'magrittr' successfully unpacked and MD5 sums checked
# package 'pillar' successfully unpacked and MD5 sums checked
# package 'pkgconfig' successfully unpacked and MD5 sums checked
# package 'vctrs' successfully unpacked and MD5 sums checked
# package 'digest' successfully unpacked and MD5 sums checked
# package 'glue' successfully unpacked and MD5 sums checked
# package 'gtable' successfully unpacked and MD5 sums checked
# package 'isoband' successfully unpacked and MD5 sums checked
# package 'rlang' successfully unpacked and MD5 sums checked
# package 'scales' successfully unpacked and MD5 sums checked
# package 'tibble' successfully unpacked and MD5 sums checked
# package 'withr' successfully unpacked and MD5 sums checked
# package 'ggplot2' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\dudas\AppData\Local\Temp\RtmpETfPua\downloaded_packages

# %%
# %%R
# library("ggplot2")
# data(mpg, package="ggplot2") # alternate source: "http://goo.gl/uEeRGu")
# theme_set(theme_bw())  # pre-set the bw theme.
#
# g <- ggplot(mpg, aes(cty, hwy))
#
# # Scatterplot
# g + geom_point() +
#   geom_smooth(method="lm", se=F) +
#   labs(subtitle="mpg: city vs highway mileage",
#        y="hwy",
#        x="cty",
#        title="Scatterplot with overlapping points",
#        caption="Source: a subset of the fuel economy data that the EPA makes available on http://fueleconomy.gov")
# Out:
# R[write to console]: `geom_smooth()` using formula 'y ~ x'
